# %% [markdown]
# # 3. Web Scraping - Selenium
#
# <img src = 'https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-2.png' >
#
#
#
# Dans cet exercice, nous utiliserons la bibliothèque Selenium afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [Doctolib](https://www.doctolib.fr/dentiste/paris)
# Nous continuerons là où Beautifullsoup montrait ses limites en collectant de manière automatisée toutes les pages référencées par Doctolib.
#
#
# - Partie 2 : [Les Echos](https://www.lesechos.fr/)
# Nous collecterons les articles correspondants à la thématique `Intelligence artificielle`.
#
#
#
# # **Partie 1 - [Doctolib](https://www.doctolib.fr/)**
#
#
# <img src='https://upload.wikimedia.org/wikipedia/fr/thumb/7/7f/Logo-doctolib.svg/640px-Logo-doctolib.svg.png'>
#
#
# Les informations que nous souhaitons collecter sont les suivantes :
# - le nom du praticien
# - la profession du praticien
# - l'adresse du praticien
# - la ville du praticien
# - l'image de la fiche Doctolib du praticien
#
#
#
# ## 3.1 Installez la bibliothèque Selenium
# Utilitisez la commande suivante dans votre terminal :  `pip install selenium`

# %% [markdown]
# ## 3.2 Télécharger le webdriver [chrome](https://chromedriver.chromium.org/downloads)
# Placez le ensuite dans le dossier Web-scraping

# %% [markdown]
# ## 3.3 Importer l'objet `webdriver`de la bibliothèque de `selenium`
# Importez également `By` depuis `selenium.webdriver.common.by`

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from IPython.display import display
import json
import time

# %% [markdown]
# ## 3.4 Deffinissez une variable `driver = webdriver.Chrome(DRIVER_PATH)`.
# Où `DRIVER_PATH` est le chemin du web driver téléchargé à la question **3.2** ==> `"./chromedriver"`.

# %%
driver = webdriver.Chrome()

# %% [markdown]
# ## 3.5 Utilisez la méthode `get(BASE_URL)` de l'objet `driver` puis notez vos observations.
# `BASE_URL`est le lien pointant vers le site de Doctolib `"https://www.doctolib.fr/dentiste/paris"`

# %%
BASE_URL = "https://www.doctolib.fr/dentiste/paris"

# %%
driver.get(BASE_URL)

# %% [markdown]
# ## 3.6 Affichez l'adresse url courante ainsi que le titre de la page.

# %%
driver.title
# Out:
# 'Chirurgien-dentiste Paris 75000 : Prenez rendez-vous en ligne | Doctolib'

# %% [markdown]
# ## 3.7 Récupérez dans une variable `selection` la liste des praticients présents sur la page.
# Utilisez la méthéode `find_elements`, cette méthode prend deux arguments `By.CLASS_NAME` ainsi que le nom de la class recherchée sur la page.

# %%
selec = driver.find_elements(By.CLASS_NAME, "search-result-card")
selection = []
print(selec[1].find_elements(By.CLASS_NAME, "dl-text-neutral-130")[2].text)
# Out:
# 75019 Paris

# %% [markdown]
# ## 3.8 Affichez les information du premier élément de `selection` via son instance `text``.

# %%
for i in selec:
        data = {}
        data["nom"] = i.find_element(By.CLASS_NAME, "dl-p-doctor-result-link").text
        data["profesion"] = i.find_element(By.CLASS_NAME, "dl-doctor-card-speciality-title").text
        data["adresse"] = i.find_elements(By.CLASS_NAME, "dl-text-neutral-130")[1].text
        data["ville"] = i.find_elements(By.CLASS_NAME, "dl-text-neutral-130")[2].text
        data["image"] = i.find_element(By.CLASS_NAME, "dl-image").get_attribute("src")

        selection.append(data)

# %%
print(selection)
# Out:
# [{'nom': 'Centre médical et dentaire Opéra', 'profesion': 'Centre médical et dentaire', 'adresse': '31 Rue de Caumartin', 'ville': '75009 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/qiusrypdpuh8rghic7yf'}, {'nom': 'Dr Benamar SEDDIKI', 'profesion': 'Chirurgien-dentiste', 'adresse': '13 Rue Armand Carrel', 'ville': '75019 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ry8dcsrzfj0nxvj0odjr'}, {'nom': 'Dr Cathy BOUBLIL', 'profesion': 'Chirurgien-dentiste', 'adresse': '120 Rue Brancion', 'ville': '75015 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/oi2gcq17at5pwkqtyggz'}, {'nom': 'Dr Sylvaine Goupy', 'profesion': 'Chirurgien-dentiste', 'adresse': '107 Rue de Reuilly', 'ville': '75012 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/sestoscf7pahqy1fbsb0'}, {'nom': 'Dr Nicolas GIRARD', 'profesion': 'Chirurgien-dentiste', 'adresse': '12 Rue La Boétie', 'ville': '75008 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/xlnsj9fynashmbojstif'}, {'nom': "Centre dentaire, d'orthodontie et de pédodontie Reuilly Diderot", 'profesion': 'Centre dentaire', 'adresse': '97 Boulevard Diderot', 'ville': '75012 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/m6vlon3kuswpibc6sfjr'}, {'nom': 'Dr Michel Sala', 'profesion': 'Chirurgien-dentiste', 'adresse': '137 Rue du Chemin Vert', 'ville': '75011 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/wnpezhjkhpwxz5ti66u7'}, {'nom': 'Dr Patrick SULTAN', 'profesion': 'Chirurgien-dentiste', 'adresse': '16 Rue du Temple', 'ville': '75004 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/xmvbydmhyhhmhy8ns2tq'}, {'nom': 'Dr Pierre Cohen', 'profesion': 'Chirurgien-dentiste', 'adresse': '12 Rue du Faubourg Saint-Martin', 'ville': '75010 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/jmtozu714xw3ytokm937'}, {'nom': 'Clinadent - Centre Dentaire Paris 15, Felix Faure', 'profesion': 'Centre dentaire', 'adresse': '88 Avenue Félix Faure', 'ville': '75015 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/vuwhlq0w4z2gpi6bj3db'}, {'nom': 'Dr Elisabeth Feredj', 'profesion': 'Chirurgien-dentiste', 'adresse': '77 Avenue Emile Zola', 'ville': '75015 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/krutil1ui9yem7lg79rd'}, {'nom': 'Dr Vincent BAILLEUL', 'profesion': 'Chirurgien-dentiste', 'adresse': '212 Avenue du Maine', 'ville': '75014 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ic1nbpwyk6kawsexzhpa'}, {'nom': 'Dr Diana MARQUES', 'profesion': 'Chirurgien-dentiste', 'adresse': '22 Rue Myrha', 'ville': '75018 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/bkqii2aru8qayj5l1hv8'}, {'nom': 'Dr Lamia ABDAT', 'profesion': 'Chirurgien-dentiste', 'adresse': '110 rue Petit', 'ville': '75019 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/at63c5rwdbohfnqslb0w'}, {'nom': 'Dr Bruno COHEN SCALI', 'profesion': 'Chirurgien-dentiste', 'adresse': '11 Rue des Moines', 'ville': '75017 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ytzfooitqusmctwt9ahh'}, {'nom': 'Dr Stéphanie HURET', 'profesion': 'Chirurgien-dentiste', 'adresse': '8 Rue René Goscinny', 'ville': '75013 Paris', 'image': 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/p5ffvredj9b7ja4xa ...

# %%
df = pd.DataFrame(selection)
display(df)
# Out:
#                                                   nom  \
# 0                    Centre médical et dentaire Opéra
# 1                                  Dr Benamar SEDDIKI
# 2                                    Dr Cathy BOUBLIL
# 3                                   Dr Sylvaine Goupy
# 4                                   Dr Nicolas GIRARD
# 5   Centre dentaire, d'orthodontie et de pédodonti...
# 6                                      Dr Michel Sala
# 7                                   Dr Patrick SULTAN
# 8                                     Dr Pierre Cohen
# 9   Clinadent - Centre Dentaire Paris 15, Felix Faure
# 10                                Dr Elisabeth Feredj
# 11                                Dr Vincent BAILLEUL
# 12                                   Dr Diana MARQUES
# 13                                     Dr Lamia ABDAT
# 14                               Dr Bruno COHEN SCALI
# 15                                 Dr Stéphanie HURET
# 16                                Dr Jessica SCHERMAN
# 17                                    Dr Alain AFLALO
# 18                                 Dr Michel Abi Harb
# 19                                  Dr Gilles GROSMAN
#
#                      profesion                          adresse        ville  \
# 0   Centre médical et dentaire              31 Rue de Caumartin  75009 Paris
# 1          Chirurgien-dentiste             13 Rue Armand Carrel  75019 Paris
# 2          Chirurgien-dentiste                 120 Rue Brancion  75015 Paris
# 3          Chirurgien-dentiste               107 Rue de Reuilly  75012 Paris
# 4          Chirurgien-dentiste                 12 Rue La Boétie  75008 Paris
# 5              Centre dentaire             97 Boulevard Diderot  75012 Paris
# 6          Chirurgien-dentiste           137 Rue du Chemin Vert  75011 Paris
# 7          Chirurgien-dentiste                 16 Rue du Temple  75004 Paris
# 8          Chirurgien-dentiste  12 Rue du Faubourg Saint-Martin  75010 Paris
# 9              Centre dentaire            88 Avenue Félix Faure  75015 Paris
# 10         Chirurgien-dentiste             77 Avenue Emile Zola  75015 Paris
# 11         Chirurgien-dentiste              212 Avenue du Maine  75014 Paris
# 12         Chirurgien-dentiste                     22 Rue Myrha  75018 Paris
# 13         Chirurgien-dentiste                    110 rue Petit  75019 Paris
# 14         Chirurgien-dentiste                11 Rue des Moines  75017 Paris
# 15         Chirurgien-dentiste              8 Rue René Goscinny  75013 Paris
# 16         Chirurgien-dentiste           6 Rue de l'Abbé Groult  75015 Paris
# 17         Chirurgien-dentiste         79 BOULEVARD DE GRENELLE  75015 PARIS
# 18         Chirurgien-dentiste       16 Rue George Bernard Shaw  75015 Paris
# 19         Chirurgien-dentiste          59 Rue de la Convention  75015 Paris
#
#                                                 image
# 0   https://media.doctolib.com/image/upload/q_auto...
# 1   https://media.doctolib.com/image/upload/q_auto...
# 2   https://media.doctolib.com/image/upload/q_auto...
# 3   https://media.doctolib.com/image/upload/q_auto...
# 4   https://media.doctolib.com/image/upload/q_auto...
# 5   https://media.doctolib.com/image/upload/q_auto...
# 6   https://media.doctolib.com/image/upload/q_auto...
# 7   https://media.doctolib.com/image/upload/q_auto...
# 8   https://media.doctolib.com/image/upload/q_auto...
# 9   https://media.doctolib.com/image/upload/q_auto...
# 10  https://media.doctolib.com/image/upload/q_auto...
# 11  https://media.doctolib.com/image/upload/q_auto...
# 12  https://media.doctolib.com/image/upload/q_auto...
# 13  https://media.doctolib.com/image/upload/q_auto...
# 14  https://media.doctolib.com/image/upload/q_auto...
# 15  https://media.doctolib.com/image/upload/q_auto...
# 16  https://media.doctolib.com/image/upload/q_auto...
# 17  https://media.doctolib.com/image/upload/q_auto...
# 18  https://media.doctolib.com/image/upload/q_auto...
# 19  https://media.doctolib.com/image/upload/q_auto...

# %%
driver.find_element(By.ID, ':r0:').send_keys("Bonjour")

# %%
from selenium.webdriver.common.keys import Keys

# %%
Keys.CLEAR
# Out:
# '\ue005'

# %%
driver.find_element(By.ID, ':r0:').clear()

# %%
driver.find_element(By.ID, ':r0:').send_keys("Dentiste Paris")

# %%
driver.find_elements(By.CLASS_NAME, "Tappable-inactive dl-button-primary searchbar-submit-button dl-button dl-button-size-medium".replace(' ', '.'))[0].click()

# %% [markdown]
# ## 3.9 Recherchez à nouveau à l'aide de la méthode `find_element` la photo du premier praticien figurant dans la liste ``selection``.

# %%
print(selec[2])
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cbc16ba697b2b36d3a858a4139543d96", element="53B47E23BD6D7BBDD023317D740360E9_element_57")>

# %%
print(driver.find_element(By.CLASS_NAME, 'dl-card-picture'))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cbc16ba697b2b36d3a858a4139543d96", element="53B47E23BD6D7BBDD023317D740360E9_element_162")>

# %% [markdown]
# ## 3.10 Récupérez à présent le lien de cette image en utilisant la méthode `get_attribute`.

# %% [markdown]
# ## 3.11 Créez une fonction `collect_data` qui renvoie un fichier `json` contenant les informations de tous les praticiens ainsi que leurs photos de profil.

# %%
def collect_data(sele):
    #creer un fichier json avec les données
    with open('Donner.json', 'w',encoding='utf8') as json_file:
        json.dump(sele, json_file,                ensure_ascii=False,
    indent=4)

# %%
collect_data(selection)

# %% [markdown]
# ## 3.9 Automatisez la collecte sur les pages 5 premières pages de résultats.

# %%
suivant = driver.find_element(By.CLASS_NAME,"next-link")

# %%
suivant.click()

# %% [markdown]
# # **Partie 2 - Collectes automatisée | [Les Echos](https://www.lesechos.fr/)**
#
#
#
# <br>
#
# <br>
#
#
# <img src = 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/bb/Les_echos_%28logo%29.svg/1200px-Les_echos_%28logo%29.svg.png'>
#
# <br><br>
#
# Les informations que nous souhaitons collecter sont les suivantes :
#
# - l’auteur,
# - la date de publication,
# - le titre,
# - le contenu de la page,

# %%
BASE_URL = "https://www.lesechos.fr/"
driver.get(BASE_URL)

# %%
recherche =  "intelligence artificielle"

# %%
bouton = driver.find_elements(By.TAG_NAME, 'button')

# %%
def rechercheIA():
    try:
        for i in bouton:
            if(i.get_attribute("aria-label") == "Recherche"):
                i.click()
                time.sleep(2)
        driver.find_element(By.TAG_NAME, 'input').send_keys(recherche)
        driver.find_element(By.TAG_NAME, 'input').send_keys(Keys.ENTER)
    except:
        driver.find_element(By.TAG_NAME, 'input').send_keys(recherche)
        driver.find_element(By.TAG_NAME, 'input').send_keys(Keys.ENTER)

# %%
rechercheIA()

# %%
ListeArticle = driver.find_elements(By.CLASS_NAME, "PiyDN")

# %%
ListeArticle[0].text
# Out:
# "DÉCRYPTAGE\nLe CAC 40 caracole à son plus haut niveau historique \nPublié à 10:12\nMis à jour à 11:09\nLes Bourses mondiales sont portées par un vent d'euphorie en cette fin d'année. L'inflation décélère nettement et les investisseurs parient sur un assouplissement marqué des politiques monétaires de la Fed et de la BCE.\nMarchés financiers"

# %%
driver.find_element(By.CLASS_NAME, "jAjGAp").text
# Out:
# 'Bastien Bouchaud'

# %%
driver.find_element(By.CLASS_NAME, "eJxzlO").text
# Out:
# 'Publié le 12 déc. 2023 à 10:12'

# %%
driver.find_element(By.CLASS_NAME, "post-paywall").text
# Out:
# "La saison des fêtes a pris de l'avance en Bourse. L'indice CAC 40 vient battre, en séance, son record historique à la Bourse de Paris. A Francfort, le DAX évolue déjà au plus haut niveau de son histoire. Wall Street est \ufeffégalement enthousiaste : le S&P 500 a retrouvé son niveau de mars 2022, tandis que le Nasdaq à forte coloration technologique est au plus haut depuis début avril 2022.\nLes Bourses mondiales sont portées par un vent d'euphorie en cette fin d'année. En cause, l'arrivée tant attendue de la désinflation et la perspective de politiques monétaires plus accommodantes l'an prochain. Le scénario d'un atterrissage en douceur de l'économie, qui verrait les profits des entreprises se maintenir à des niveaux historiquement élevés, donne des ailes aux investisseurs."

# %%
driver.find_element(By.CLASS_NAME, "biWaWM").text
# Out:
# 'Le CAC 40 caracole à son plus haut niveau historique '

# %%
ListeDesDonner = []

# %%
ListeArticle[1].find_element(By.TAG_NAME, 'h3').text
# Out:
# 'Conex passe dans le giron de 21 Invest France '

# %%
ListeArticle[0].find_elements(By.TAG_NAME, 'a')[1].click()

# %%
nbart = len(ListeArticle)

# %%
for i in range(nbart):
    ListeArticle = driver.find_elements(By.CLASS_NAME, "PiyDN")
    data = {}
    ListeArticle[i].find_elements(By.TAG_NAME, 'a')[1].click()
    time.sleep(2)
    try:
        data["auteur"] = driver.find_element(By.CLASS_NAME, "sc-ap0kf6-0").text
    except:
        data["auteur"] = "inconnue"
    try:
        data["date de publication"] = driver.find_element(By.CLASS_NAME, "sc-17ifq26-0").text
    except:
        data["date de publication"] = "inconnue"
    try:
        data["contenue"] = driver.find_element(By.CLASS_NAME, "post-paywall").text
    except:
        data["contenue"] = "inconnue"
    try:
        data["titre"] = driver.find_element(By.CLASS_NAME, "biWaWM").text
    except:
        data["titre"] = "inconnue"
    ListeDesDonner.append(data)
    rechercheIA()

    time.sleep(2)

# %%
ListeDesDonner
# Out:
# [{'auteur': 'Bastien Bouchaud',
#   'date de publication': 'Publié le 12 déc. 2023 à 10:12',
#   'contenue': "La saison des fêtes a pris de l'avance en Bourse. L'indice CAC 40 vient battre, en séance, son record historique à la Bourse de Paris. A Francfort, le DAX évolue déjà au plus haut niveau de son histoire. Wall Street est \ufeffégalement enthousiaste : le S&P 500 a retrouvé son niveau de mars 2022, tandis que le Nasdaq à forte coloration technologique est au plus haut depuis début avril 2022.\nLes Bourses mondiales sont portées par un vent d'euphorie en cette fin d'année. En cause, l'arrivée tant attendue de la désinflation et la perspective de politiques monétaires plus accommodantes l'an prochain. Le scénario d'un atterrissage en douceur de l'économie, qui verrait les profits des entreprises se maintenir à des niveaux historiquement élevés, donne des ailes aux investisseurs.",
#   'titre': 'Le CAC 40 caracole à son plus haut niveau historique '},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le
},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 19:35',
#   'contenue': "La réindustrialisation de la France pourrait-elle être le ciment politique dont manque tant l'exécutif actuellement, en pleine débâcle sur son projet de loi immigration ? C'est en tout cas le pari que veut faire Emmanuel Macron.\nEn déplacement à Toulouse sur le site d'Airbus, ancienne start-up européenne, a-t-il rappelé, le président de la République a transformé la célébration des deux ans du plan d'investissement France 2030 en remobilisation nationale aux accents gaullistes.",
#   'titre': "Comment Emmanuel Macron veut redonner de l'élan à la réindustrialisation"},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 18:46',
#   'contenue': "Incontournable dans les télécoms européens et outsider dans l'informatique en ligne, le groupe Iliad connaît mieux que quiconque les différences entre ces deux marchés. Cloisonnés derrière des frontières nationales, les « telcos » sont autant régulés que le cloud est un far-west mondial dominé par les cow-boys américains. Mais pas de quoi effrayer l'entrepreneur Xavier Niel après ses succès dans les box Internet.\nEn pointe sur l'intelligence artificielle (IA) à la française, le milliardaire mise sur les récents développements de cette technologie pour doper la filiale Scaleway, spécialisée dans la location en ligne de puissance informatique. Créée en 2005 sous le nom de « Dedibox », la société emploie aujourd'hui près de 600 collaborateurs. Il y a quatre ans, elle n'en comptait que 200. Et ce n'est peut-être qu'un début… Sa maison mère vient de lui libeller un chèque de 100 millions d'euros, soit l'équivalent de son chiffre d'affaires 2023. Jamais elle n'aura eu autant de moyens à sa disposition pour grandir.",
#   'titre': "Xavier Niel engage Iliad dans le pari de l'IA pour sa filiale Scaleway "},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 17:47',
#   'contenue': "Après une année d'immersion dans le monde de ChatGPT, il est devenu évident qu'à l'exception de Microsoft , tous les principaux acteurs de l'intelligence artificielle classique ont été dépassés par son ascension fulgurante. En réponse, les géants de la technologie ont accéléré et réorienté leurs efforts de développement interne vers l'intelligence artificielle générative (IAG). En un temps record, ils sont devenus d'importants investisseurs, rivalisant avec le capital-risque, et ont notablement réduit son impact grâce à des partenariats de plusieurs milliards de dollars avec des start-up axées sur l'IAG.\nSelon PitchBook, un montant total de 23,2 milliards de dollars a été injecté dans des start-up spécialisées en IAG jusqu'au 15 octobre 2023, soit une augmentation de 250,2 % par rapport à l'année précédente. Cependant, en dehors de ces partenariats majeurs avec des entreprises, les investissements traditionnels en capital-risque ne parviennent qu'à égaler le montant total levé par les leaders de l'IAG en 2021, avec seulement 7,9 milliards de dollars investis dans des tours de financement conventionnels jusqu'à présent.",
#   'titre': 'Opinion | IA générative : quels nouveaux rapports de force entre investisseurs ? '},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 16:37',
#   'contenue': "L'automatisation de l'information par l'IA est en marche. Le géant allemand Axel Springer, maison mère de « Bild » et « Die Welt » et qui a racheté en 2021 le média Politico, créé aux Etats-Unis, a annoncé le lancement à l'été 2024 d'un « générateur de tendances d'actualité exclusivement dirigé par l'intelligence artificielle », selon un communiqué du groupe publié vendredi.\nLe service opérera sous la marque « Upday », celle de l'actuel agrégateur d'information lancé par le groupe en 2016 sous la forme d'une application mobile en partenariat avec Samsung. La coopération entre les deux entreprises s'achève d'ici la fin de l'année, mais le service restera disponible sur les mobiles du géant de l'électronique pendant une période de transition de plus d'un an, précise Axel Springer.",
#   'titre': "Le groupe Axel Springer remet son agrégateur Upday entre les mains de l'IA "},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à
#   'titre': 'Portables, chatbots, robots : faut-il avoir peur de ces nouveaux doudous ?'},
#  {'auteur': 'inconnue',
#   'date de publication': 'inconnue',
#   'contenue': 'inconnue',
#   'titre': 'inconnue'},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 13:19',
#   'contenue': "Les tendances de recherche sur Google donnent un bon condensé de l'actualité de l'année et des préoccupations des Français. Le leader des moteurs de recherche a publié son bilan annuel des requêtes, fondé sur les mots ou expressions les plus recherchées en 2023 par rapport à 2022 en France. Le géant américain classe les recherches par grandes catégories (actualités, chanteurs, films, personnalités politiques, etc.).\nChatGPT, le robot conversationnel d'OpenAI, qui fait le buzz depuis plusieurs mois, arrive en tête des recherches sur l'actualité. L'outil symbole de l'intelligence artificielle générative, qui est sorti fin 2022, a passionné le grand public. Et ce, dès le départ : dès janvier, le robot conversationnel avait dépassé le cap des 100 millions d'utilisateurs, selon UBS , du jamais vu en si peu de temps.",
#   'titre': 'ChatGPT se hisse au sommet des recherches Google '},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 11:14',
#   'contenue': "On connaissait le bar à salades, le bar à huîtres, le bar à ongles… Mais chez Bouygues Telecom, c'est un « bar à prompts » qui vient d'être installé, sur son Technopole de Meudon, en banlieue parisienne. Deux à trois fois par mois, près de la cantine, des ingénieurs de l'opérateur apprennent aux salariés les meilleures façons de dialoguer avec un robot d'intelligence artificielle comme ChatGPT. Car plus les questions posées (les fameux prompts) sont pertinentes, moins le robot aura tendance à « halluciner » et à répondre à côté.\n« L'IA générative, c'est une révolution de la même ampleur qu'Internet, résume Stéphane Allaire, directeur de l'innovation chez Bouygues Telecom. Nous voulons donc être une entreprise 'AIGen-ready'. » Pour cela, l'opérateur a déjà formé 600 collaborateurs, sur un objectif de 3.000 à terme (soit un tiers des effectifs). Depuis juillet, tous les salariés peuvent aussi utiliser un ChatGPT sécurisé pour traduire du texte, résumer des réunions, etc.",
#   'titre': "« Bar à prompts », « conseiller augmenté »… les télécoms français s'emparent de l'IA générative "},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 10:30',
#   'contenue': "Dans les conférences traitant d'intelligence artificielle, dans les dîners en ville comme dans les comex, le thème du retard européen prend souvent des tournures passionnées.\nCertains n'hésitent pas à se draper dans la défense de la souveraineté pour énoncer un assortiment de mesures plus interventionnistes les unes que les autres : investissement public dans une filière de construction de puces haute performance en France, interdiction des services numériques non français dans l'administration, ou même blocage pur et simple de certaines plateformes américaines.",
#   'titre': 'Souveraineté numérique : dépasser les idées reçues pour avancer '},
#  {'auteur': 'Bastien Bouchaud',
#   'date de publication': 'Publié le 11 déc. 2023 à 9:34',
#   'contenue': "Ce n'est décidément pas l'année des vendeurs à découvert. Le célèbre « short seller » Jim Chanos a jeté l'éponge le mois dernier après une carrière de quarante ans à Wall Street. Et les pertes s'accumulent pour les irréductibles sceptiques des valeurs cryptos alors que le bitcoin poursuit son spectaculaire rebond. La reine des cryptos a rebondi de 160 % depuis le début de l'année. Elle évoluait vendredi à plus de 43.000 dollars , son niveau le plus élevé depuis avril 2022.\nLe bitcoin a entraîné dans son sillage tout un ensemble de valeurs cotées liées à l'écosystème crypto, à commencer par la plateforme de trading Coinbase et MicroStrategy, qui détient près de 175.000 bitcoins dans sa trésorerie. Les cours de ces deux valeurs ont été multipliés par près de 4 depuis le début de l'année. C'est mieux que Nvidia, le champion de l'intelligence artificielle en Bourse, dont le cours a été multiplié par 3.",
#   'titre': 'La lourde facture des vendeurs à découvert sur les actions cryptos '},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 8:30',
#   'contenue': "Votre entreprise Mistral AI vient de lever 385 millions d'euros pour développer des modèles prometteurs d'intelligence artificielle. Pour beaucoup, cette technologie est aussi porteuse de risques. Qu'en pensez-vous ?\nAvec Timothée Lacroix et Guillaume Lample, nous avons créé Mistral AI parce que deux choses nous tenaient à coeur : faire émerger un champion européen et promouvoir une approche ouverte de la technologie. Il nous semblait impératif que des outils aussi structurants que les modèles de langage pour nos économies et nos démocraties \ufeffne soient pas contrôlés uniquement par un très petit nombre d'entreprises - par ailleurs toutes américaines ou chinoises.",
#   'titre': "« L'Europe peut être à la pointe de la révolution de l'IA », selon le patron de Mistral AI "},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 8:11',
#   'contenue': "En anglais, on appelle ça le syndrome Fomo (« fear of missing out »), c'est-à-dire la peur de passer à côté de quelque chose d'important. Les fonds de capital-risque connaissent cela par coeur : à intervalles réguliers, ils se battent comme des chiffonniers pour entrer au capital de start-up à gros potentiel.\nCe fut le cas, au printemps 2023, lors du tour d'amorçage de 105 millions d'euros de Mistral AI. « C'était la folie », se souvient un capital-risqueur qui n'a pas pu monter à bord du TGV français de l'intelligence artificielle. Après une bataille âpre, c'est finalement le fonds américain Lightspeed Venture Partners qui avait mené l'opération grâce à son investisseur « frenchy » : Antoine Moyroud.",
#   'titre': "French Tech : Antoine Moyroud, l'investisseur qui a parié en premier sur Mistral AI "},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 8:00',
#   'contenue': "Naïo,VitiBot ou Sabi Agri… Les premiers robots viticoles et maraîchers font déjà parler d'eux dans les campagnes. Leur cousin, le Grillon, conçu et produit par la jeune société Cyclair au beau milieu des champs, dans la Vienne, s'attaque au désherbage mécanique et autonome des grandes cultures, pour remplacer les herbicides et notamment le glyphosate.\nUne autre paire de manches, selon son président et cofondateur, Sébastien Gorry : « On ne peut pas se fier à un GPS pour travailler dans du maïs. Il faut une technologie capable de distinguer la culture de l'adventice », autrement dit la mauvaise herbe. Quand la vigne est plantée pour trente ans, la culture annuelle, elle, se différencie peu de la végétation indésirable dans ses premières semaines.",
#   'titre': 'Cyclair finance son robot désherbeur de grandes cultures intelligent '},
#  {'auteur': 'inconnue',
#   'date de publication': 'Publié le 11 déc. 2023 à 8:00',
#   'contenue': "C'était une critique qui revenait, à l'occasion du premier tour de table de Mistral AI (105 millions d'euros), réalisé quelques mois plus tôt. La start-up deviendrait-elle américaine ? « Nous gardons le contrôle du board », précise aux « Echos » Arthur Mensch, cofondateur de Mistral AI, qui reste aussi majoritaire avec ses associés à l'occasion de sa seconde levée de fonds, cette fois-ci de 385 millions d'euros.\nLors du premier tour de Mistral AI, c'est l'américain Lightspeed Venture qui a capté la majeure partie du capital (10 %), suivi d'Hillspire (2 %), le family office d'Eric Schmidt, ex-PDG de Google. Cette fois-ci, c'est Andreessen Horowitz, le fonds de capital-risque californien star de la Silicon Valley, qui dirige la levée. Selon Bloomberg, le fonds aurait injecté, à lui seul, environ 200 millions d'euros, suivi de Lightspeed.",
# 19          inconnue   Publié le 11 déc. 2023 à 6:51
#
#                                              contenue  \
# 0   La saison des fêtes a pris de l'avance en Bour...
# 1   La société d'investissement 21 Invest France p...
# 2   TotalEnergies n'a eu aucun mal à trouver l'adr...
# 3   Retour aux fondamentaux : c'est sa séquence su...
# 4   La réindustrialisation de la France pourrait-e...
# 5   Incontournable dans les télécoms européens et ...
# 6   Après une année d'immersion dans le monde de C...
# 7   L'automatisation de l'information par l'IA est...
# 8    «Oliver fait partie de ma vie. Je le prends d...
# 9                                            inconnue
# 10  Les tendances de recherche sur Google donnent ...
# 11  On connaissait le bar à salades, le bar à huît...
# 12  Dans les conférences traitant d'intelligence a...
# 13  Ce n'est décidément pas l'année des vendeurs à...
# 14  Votre entreprise Mistral AI vient de lever 385...
# 15  En anglais, on appelle ça le syndrome Fomo (« ...
# 16  Naïo,VitiBot ou Sabi Agri… Les premiers robots...
# 17  C'était une critique qui revenait, à l'occasio...
# 18  « Il y a six mois, je ne savais même pas ce qu...
# 19  Actualité des entreprises, Bourses, événements...
#
#                                                 titre
# 0   Le CAC 40 caracole à son plus haut niveau hist...
# 1      Conex passe dans le giron de 21 Invest France
# 2   TotalEnergies fait une razzia de start-up à St...
# 3   Start-up de France 2030 : en attendant le « up »
# 4   Comment Emmanuel Macron veut redonner de l'éla...
# 5   Xavier Niel engage Iliad dans le pari de l'IA ...
# 6   Opinion | IA générative : quels nouveaux rappo...
# 7   Le groupe Axel Springer remet son agrégateur U...
# 8   Portables, chatbots, robots : faut-il avoir pe...
# 9                                            inconnue
# 10  ChatGPT se hisse au sommet des recherches Google
# 11  « Bar à prompts », « conseiller augmenté »… le...
# 12  Souveraineté numérique : dépasser les idées re...
# 13  La lourde facture des vendeurs à découvert sur...
# 14  « L'Europe peut être à la pointe de la révolut...
# 15  French Tech : Antoine Moyroud, l'investisseur ...
# 16  Cyclair finance son robot désherbeur de grande...
# 17  La faible présence des fonds européens dans le...
# 18  Intelligence artificielle : Mistral AI devient...
# 19  LE FIL INFO - Ce qu'il faut retenir de la jour...

# %% [markdown]
# ---
# # **Partie 3 : Programation Orientée Objet et Gestion d'une base de données**
#
#
#
# ### **1. Définition d'une Classe**
# **Definition**
#
# La programmation orientée objet (POO) est un paradigme de programmation qui repose sur le concept d'objets. Dans ce paradigme, le code est organisé autour d'entités appelées "objets", qui représentent des instances concrètes ou abstraites de concepts du monde réel. Chaque objet peut avoir des propriétés (appelées attributs) et des comportements (appelés méthodes).
#
# Voici quelques concepts clés de la programmation orientée objet :
#
# - **Objets** : Les objets sont des instances spécifiques d'une classe, qui est un modèle ou un plan pour créer des objets. Par exemple, si une classe est définie pour représenter des voitures, un objet spécifique pourrait être une voiture particulière.
#
# - **Classes** : Les classes sont des structures qui définissent la manière dont les objets sont créés. Elles définissent les attributs (caractéristiques) et les méthodes (comportements) que les objets de la classe auront. Une classe est une sorte de modèle à partir duquel des objets peuvent être créés.
#
# - **Encapsulation** : L'encapsulation est le principe de regrouper les données (attributs) et les méthodes qui les manipulent au sein d'une même entité, c'est-à-dire une classe. Cela permet de cacher les détails d'implémentation et d'isoler le fonctionnement interne de l'objet.
#
# - **Héritage** : L'héritage est un mécanisme qui permet à une classe d'hériter des propriétés et des méthodes d'une autre classe. Cela favorise la réutilisation du code et la création de hiérarchies de classes.
#
# - **Polymorphisme** : Le polymorphisme permet à un même nom de méthode d'avoir des comportements différents en fonction du contexte. Il existe deux types de polymorphisme : le polymorphisme statique (surcharge) et le polymorphisme dynamique (redéfinition).
#
# - **Abstraction** : L'abstraction consiste à simplifier un concept complexe en modélisant uniquement les aspects pertinents tout en masquant les détails complexes.
#
#       # Déclaration d'une classe, paramètre 1 et 2 seront
#
#       class NomDeLaClasse:
#         # Définition des attributs au moment de l'instanciation
#         def __init__(self, parametre1, parametre2):
#           self.parametre1 = parametre1
#           self.parametre2 = parametre2
#
#         def __repr__(self):
#           return "Exemple de retour"
#
#         # Définition d'une méthode
#         def nom_de_la_methode(self, p1, p2):
#           self.value = p1 * p2 # Création d'un nouvel attribut
#
#       # Instance de classe
#       objet = NomDeLaClasse('parametre1', 'parametre2')
#
#       # Héritage :
#       class ClasseFille(NomDeLaClasseMère):
#         def __init__(self, parametre1, parametre2, parametre3):
#           NomDeLaClasseMère.__init__(self, parametre1, parametre2)
#           self.parametre3 = parametre3
#
#         # Méthode utilisable uniquement dans la classe :
#         def __methode_encapsulee(self):
#           print("Test")
#
#
# - __init__: permet de définir les attributs nécessaires à l'objet lors de son instanciation.
# - __repr__: permet de définir le type d'objet retourné par défaut.
# - __str__ : permet de définir ce qui est affiché par défaut lorsque l'on print un objet.
# - __add__ : permet de définir ce ci se produit lorsque l'on additionne des objets entre eux.

# %%
# Définir une classe
class Voiture:
    def __init__(self, brand, color, km):
        self.brand = brand
        self.color = color
        self.km = km
    def travel(self, position:str,destination:str,distance:str) -> str:
        """
        Cette fonction permet de déplacer la voiture d'un point A à un point B
        """
        self.destination = destination
        self.position = position
        self.km += distance
        return f'Position actuelle {self.position}'
    
    def show_multiple_data(self,**kwargs):
        print(kwargs)
    def show_data(self,*args):
          print(args)

# %%
# Instancier un objet
voiture = Voiture("Renault", "Rouge", 100000)
voiture.show_multiple_data(name='Kevin',age=25,job='Data Scientist')
# Out:
# {'name': 'Kevin', 'age': 25, 'job': 'Data Scientist'}

# %%
voiture.show_data(*['Kevin',25,'Data Scientist'])
# Out:
# ('Kevin', 25, 'Data Scientist')

# %%
# Héritage

# %% [markdown]
# ### **2. Gestion d'une base de données avec la bibliothèque [SQLalchemy](https://docs.sqlalchemy.org/en/14/)**
#
# <img src='https://miro.medium.com/v2/resize:fit:1400/0*msfsws06ImMSJYop.jpg'>
#
# SQLAlchemy est une bibliothèque Python très populaire qui facilite l'interaction avec des bases de données relationnelles en utilisant un langage Python. Elle fournit un ensemble d'outils puissants pour travailler avec des bases de données SQL tout en offrant une abstraction flexible qui permet de travailler avec différents types de bases de données.
#
# Voici quelques caractéristiques clés de SQLAlchemy :
#
# **ORM (Object-Relational Mapping)** : SQLAlchemy propose un ORM qui permet de représenter des tables de base de données sous forme d'objets Python. Ces objets peuvent être manipulés comme n'importe quel autre objet Python, offrant ainsi une abstraction plus élevée des opérations sur la base de données.
#
# **Prise en Charge de Diverses Bases de Données** : SQLAlchemy prend en charge plusieurs types de bases de données, y compris MySQL, PostgreSQL, SQLite, Oracle, et d'autres.
#
# **Flexibilité** : Vous pouvez utiliser SQLAlchemy de manière transparente avec un ORM complet, un langage SQL pur, ou une combinaison des deux, en fonction des besoins de votre application.
#
# **Communauté Active** : SQLAlchemy est largement utilisé dans la communauté Python et dispose d'une documentation complète et d'une base d'utilisateurs active.
#
# ---
#
#
# 1. Installation de la bibliothèque : `pip install SQLAlchemy`
#
# 2. Installez [SQLite Viewer](https://marketplace.visualstudio.com/items?itemName=qwtel.sqlite-viewer) pour visualiser votre base données.
#
# <img src='https://qwtel.gallerycdn.vsassets.io/extensions/qwtel/sqlite-viewer/0.3.13/1691231169503/Microsoft.VisualStudio.Services.Icons.Default'>

# %%
# Gestion d'une base de données
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='database'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')


    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table)

        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
db.__version__
# Out:
# '2.0.23'

# %%
# Création d'une base de données
database = DataBase('data')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Travail\MASTER2\WebScraping\3. Web Scraping - Selenium _ IPSSI PRS.ipynb Cellule 65 line 2
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> # Création d'une base de données
# ----> <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=1'>2</a> database = DataBase('data')
#
# c:\Travail\MASTER2\WebScraping\3. Web Scraping - Selenium _ IPSSI PRS.ipynb Cellule 65 line 8
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=5'>6</a> self.name = name_database
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=6'>7</a> self.url = f"sqlite:///{name_database}.db"
# ----> <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=7'>8</a> self.engine = db.create_engine(self.url)
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=8'>9</a> self.connection = self.engine.connect()
#      <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/WebScraping/3.%20Web%20Scraping%20-%20Selenium%20_%20IPSSI%20PRS.ipynb#Y100sZmlsZQ%3D%3D?line=9'>10</a> self.metadata = db.MetaData()
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in warned(fn, *args, **kwargs)
#     277 @decorator
#     278 def warned(fn, *args, **kwargs):
#     279     for m in check_defaults:
#     280         if (defaults[m] is None and kwargs[m] is not None) or (
# --> 281             defaults[m] is not None and kwargs[m] != defaults[m]
#     282         ):
#     283             _warn_with_version(
#     284                 messages[m],
#     285                 versions[m],
#     286                 version_warnings[m],
#     287                 stacklevel=3,
#     288             )
#     290     if check_any_kw in messages and set(kwargs).difference(
#     291         check_defaults
#     292     ):
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\create.py:552, in create_engine(url, **kwargs)
#     548     dbapi = dialect_cls.dbapi(**dbapi_args)
#     550 dialect_args["dbapi"] = dbapi
# --> 552 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#     553 enable_from_linting = kwargs.pop("enable_from_linting", True)
#     554 if enable_from_linting:
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\url.py:754, in _get_entrypoint(self)
#     752 if m is not None:
#     753     components = m.groupdict()
# --> 754     if components["query"] is not None:
#     755         query = {}
#     757         for key, value in util.parse_qsl(components["query"]):
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:364, in load(self, name)
#     358 try:
#     359     co_varkeywords = inspect.CO_VARKEYWORDS
#     360 except AttributeError:
#     361     # https://docs.python.org/3/library/inspect.html
#     362     # The flags are specific to CPython, and may not be defined in other
#     363     # Python implementations. Furthermore, the flags are an implementation
# --> 364     # detail, and can be removed or deprecated in future Python releases.
#     365     spec = compat.inspect_getfullargspec(fn)
#     366     return spec[0], bool(spec[2])
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\__init__.py:47, in _auto_fn(name)
#      45     except ImportError:
#      46         module = __import__("sqlalchemy.dialects.sybase").dialects
# ---> 47         module = getattr(module, dialect)
#      48 elif dialect == "mariadb":
#      49     # it's "OK" for us to hardcode here since _auto_fn is already
#      50     # hardcoded.   if mysql / mariadb etc were third party dialects
#      51     # they would just publish all the entrypoints, which would actually
#      52     # look much nicer.
#      53     module = __import__(
#      54         "sqlalchemy.dialects.mysql.mariadb"
#      55     ).dialects.mysql.mariadb
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\sqlite\__init__.py:9
#       1 # sqlite/__init__.py
#       2 # Copyright (C) 2005-2022 the SQLAlchemy authors and contributors
#       3 # <see AUTHORS file>
#       4 #
#       5 # This module is part of SQLAlchemy and is released under
#       6 # the MIT License: https://www.opensource.org/licenses/mit-license.php
#       8 from . import base  # noqa
# ----> 9 from . import pysqlcipher  # noqa
#      10 from . import pysqlite  # noqa
#      11 from .base import BLOB
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\sqlite\pysqlcipher.py:99
#       8 """
#       9 .. dialect:: sqlite+pysqlcipher
#      10     :name: pysqlcipher
#    (...)
#      94
#      95 """  # noqa
#      97 from __future__ import absolute_import
# ---> 99 from .pysqlite import SQLiteDialect_pysqlite
#     100 from ... import pool
#     101 from ... import util
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\sqlite\pysqlite.py:445
#     441         else:
#     442             return DATE.result_processor(self, dialect, coltype)
# --> 445 class SQLiteDialect_pysqlite(SQLiteDialect):
#     446     default_paramstyle = "qmark"
#     447     supports_statement_cache = True
#
# File c:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\dialects\sqlite\pysqlite.py:457, in SQLiteDialect_pysqlite()
#     447 supports_statement_cache = True
#     449 colspecs = util.update_copy(
#     450     SQLiteDialect.colspecs,
#     451     {
#    (...)
#     454     },
#     455 )
# --> 457 if not util.py2k:
#     458     description_encoding = None
#     460 driver = "pysqlite"
#
# AttributeError: module 'sqlalchemy.util' has no attribute 'py2k'

# %%
# Création d'un Tableau1
database.create_table('Tableau1', id_user=db.Integer, colonne1=db.String, colonne2=db.Integer)

# %%
# Création d'un Tableau2
database.create_table('Tableau2', id_shop=db.Integer, id_colonne1=db.String, colonne2=db.Integer)

# %%
# Ajouter une ligne à la base de données
database.add_row('Tableau2', id_shop=3086, id_colonne1='Iphone')

# %%
# Ajouter plusieurs lignes à la base de données
for i in range(10):
    database.add_row('Tableau2',id_shop=i, id_colonne1='Iphone'*(i+1), colonne2=99*i)

database.select_table('Tableau2')

# %%
# Afficher le Tableau1
database.select_table('Tableau2')

# %% [markdown]
# # Exercice Collecte d’articles sur le site [Cdiscount](https://www.cdiscount.com/)
#
# <img src='https://marketplace.cdiscount.com/wp-content/uploads/2020/06/french-days-cdiscount.jpg'>
#
# Dans cet exercice nous allons collecter les informations des articles présents sur le site Cdiscount.
# Parmis une liste de produit, collectez dans une base de données les informations suivantes :
# - le nom de l’article,
# - le lien de l’image,
# - le lien de l’article
# - le prix de l’article
# - la note de l’article
#
# Nous créerons un script qui automatisera la collecte des données en prenant en compte les exceptions et qui retournera un fichier csv contenant l'ensemble de nos données. Voici la liste des produits à collecter (choisir un article) :
# - Iphone 13
# - Samsung Galaxy S21
# - Xiaomi Redmi Note 10
#
# 1. Créez une fonction `collecte_Cdiscount` qui prends en entrée une chaine de caractère (produit à collecter) et qui retourne un fichier csv contenant les produits scrappé avec la bibliothèque Selenium.
# 2. Placez vcette fonction dans un fichier `functions.py`.
# 3. Créez une page dans votre application streamlit qui demande à l'utilisateur de saisir le nom d'un produit à collecter puis fait appel à la fonction `collecte_Cdiscount` pour collecter ces produits. La collecte ne doit pas ouvrir de navigateur.
# 4. Ajoutez les données dans une base de données MySQL ou SQL Lite.
