# %% [markdown]
# # 4. Web Scraping - Scrapy
#
# <img src='https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-3.png'>
#
# Dans cet exercice, nous utiliserons la bibliothèque scrapy afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [AlloCiné](https://www.allocine.fr/film/meilleurs)
# Nous collecterons les informations des meilleurs films recensés par la platforme.
#
#
# - Partie 2 : [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
# Nous collecterons les données boursières des entreprises du CAC40.

# %% [markdown]
# # Parie 1 - Les meilleurs films selon [Allociné.fr](https://www.allocine.fr/film/meilleurs/)
#
# <img src= 'https://fr.web.img2.acsta.net/newsv7/15/10/19/21/14/237930.jpg'>
#
# L'objectif de cet exercice est de collecter les données des meilleurs films présents sur la page `https://www.allocine.fr/film/meilleurs/` du site allocine.fr.
#
# Les données que nous collecterons seront les suivantes :
# - Les titres du film
# - Les liens des images
# - Les noms des auteurs
# - Les durées des films
# - Les genres cinématographiques
# - Les scores des films
# - Les descriptions des films
# - Les dates de sortie des films
#
# ## 4.1 Installez scrapy à l'aide de la commande suivante :
#
#
# `pip install scrapy`

# %%
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.11.0-py2.py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 4.7 MB/s eta 0:00:00
# Collecting Twisted<23.8.0,>=18.9.0 (from scrapy)
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (41.0.7)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.1.0-py3-none-any.whl (11 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.3.0)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-23.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 25.3 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.3.0-py2.py3-none-any.whl (8.5 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from scrapy) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.2)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.1.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from scrapy) (4.9.3)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Collecting constantly>=15.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Collecting incremental>=21.3.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.5.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# Installing collected packages: PyDispatcher, incremental, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, constantly, Automat, Twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.7 Twisted-22.10.0 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.8.0 itemloaders-1.1.0 jmespath-1.0.1 parsel-1.8.1 protego-0.3.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.11.0 service-identity-23.1.0 tldextract-5.1.1 w3lib-2.1.2 zope.interface-6.1

# %% [markdown]
# ## 4.2 Générez un environement de travail scrapy en executant la commande suivante :

# %%
# Création du dossier WebCrawler contenant l'ensemble des fichiers utiles au fonctionnement de scrapy
# !scrapy startproject WebCrawler
# Out:
# New Scrapy project 'WebCrawler', using template directory 'C:\Users\trist\AppData\Local\Programs\Python\Python311\Lib\site-packages\scrapy\templates\project', created in:
#     C:\Travail\MASTER2\tpStreamlit\TP\WebCrawler
#
# You can start your first spider with:
#     cd WebCrawler
#     scrapy genspider example example.com

# %%
# Création du projet AlloCiné dans le dossier WebCrawler/spider
# !cd WebCrawler && scrapy genspider allocine https://www.allocine.fr/film/meilleurs
# Out:
# Spider 'allocine' already exists in module:
#   WebCrawler.spiders.allocine

# %% [markdown]
# Les fichiers de scrapy que nous manipulerons seront :
#
# 1. le fichier `items.py` qui contient les champ que nous souhaitons collecter (ex : nom des films, score, date de publication). Chaque champs sera introduit dans la class `ReviewsAllocineItem` avec la nomenclature suivante : `name = scrapy.Field()`.
#
#
# 2. le fichier `allocine.py` qui contient les fonctions permettant la collecte.

# %% [markdown]
# ## 4.3 Ajoutez dans le fichier `items.py` les champs que nous souhaitons collecter.
#
# Ajoutez dans la class `ReviewsAllocineItem(scrapy.Item)` les champs suivants,
# pour rappel la nomenclature des champs est la suivante :
#
# `name = scrapy.Field()`.
#
# - title
# - img
# - author
# - time
# - genre
# - score
# - desc
# - release
# - page

# %%
#À ajouter au fichier items.py
class ReviewsAllocineItem(scrapy.Item):
     pass

# %% [markdown]
# ## 4.3 Lancez votre terminal puis exécutez la commande suivante :
#
# C'est dans le terminale que nous intéragirons avec scrapy pour manipuler les bases du site allocine.fr

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.allocine.fr/film/meilleurs'`
#
# `fetch(url)`

# %% [markdown]
# ## 4.4 Exécutez dans votre terminal les commandes suivantes et notez vos observations.
#
# Repérez les balises correspondantes.
#
# `response`
#
# `response.css('a')`
#
# `len(response.css('a'))`
#
# `response.css('a::text')`
#
# `response.css('a')[0].attrib`
#
# `response.css('a')[0].attrib['href']`
#
# `response.css('a::text')[0].extract()`
#
# `response.css('h1.item')`
#
# `response.css('h1.item::text')`
#
# `response.css('h1.item::text')[0].extract()`
#
# `response.css('img')`

# %% [markdown]
# ## 4.5 Recherchez les informations suivantes sous forme de chaine de caractère (str) :
#
# 0. La balise qui liste l'ensemble des films
# 1. Le titre du premier film
# 2. Le lien de l'image du premier film
# 3. Le nom de l'auteur du premier film
# 4. La durée du premier film
# 5. Le genre cinématographique du premier film
# 6. Le score du premier film
# 7. La description du premier film
# 8. La date de sortie du premier film

# %%
#0. La balise qui liste l'ensemble des films
list_films = response.css('li.mdl')

#1. Le titre du premier film
title = list_films.css('a.meta-title-link::text')[0].get()

#2. Le lien de l'image du premier film
image = list_films.css('img::attr(src)')[0].get()

#3. Le nom de l'auteur du premier film
autor = list_films.css('a.blue-link::text')[0].get()

#4. La durée du premier film
time = list_films.css('div.meta-body-item.meta-body-info::text')[0].get()

#5. Le genre cinématographique du premier film
genre = list_films.css('div.meta-body-item.meta-body-info span::text')[1].get()

#6. Le score du premier film
score = list_films.css('span.stareval-note::text')[0].get()

#7. La description du premier film
desc = list_films.css('div.content-txt ::text')[0].get()

#8. La date de sortie du premier film
date = list_films.css('span.date::text')[0].get()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Travail\MASTER2\tpStreamlit\TP\4. Web Scraping - Scrapy _ IPSSI SQY.ipynb Cellule 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> # 0. La balise qui liste l'ensemble des films
# ----> <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> list_films = response.css('div.gd-col-middle')[0]
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> #1. Le titre du premier film
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> #2. Le lien de l'image du premier film
#       <a href='vscode-notebook-cell:/c%3A/Travail/MASTER2/tpStreamlit/TP/4.%20Web%20Scraping%20-%20Scrapy%20_%20IPSSI%20SQY.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> title = list_films[0].css('a.meta-title-link::text').get()
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## 4.6 Complétez le code suivante en fonction des résultats obtenus à la question précédentes

# %%
import scrapy
from scrapy import Request
from WebCrawler.WebCrawler.items import ReviewsAllocineItem


class AllocineSpider(scrapy.Spider):
    name = 'allocine'
    allowed_domains = ['www.allocine.fr']

    #Liste des pages à collecter
    start_urls = [f'https://www.allocine.fr/film/meilleurs/?page={n}' for n in range(1,10)]


    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_allocine)


    def parse_allocine(self, response):
        liste_film = list_films = response.css('li.mdl')


        # Boucle qui parcours l'ensemble des éléments de la liste des films
        for film in liste_film:
            item = ReviewsAllocineItem()

            # Nom du film
            try:
                item['title'] = list_films.css('a.meta-title-link::text')[0].get()
            except:
                item['title'] = 'None'

            # Lien de l'image du film
            try:
                item['image'] = list_films.css('img::attr(src)')[0].get()
            except:
                item['image'] = 'None'


            # Auteur du film
            try:
                item['author'] = list_films.css('a.blue-link::text')[0].get()
            except:
                item['author'] = 'None'

            # Durée du film
            try:
                item['time'] = list_films.css('div.meta-body-item.meta-body-info::text')[0].get()
            except:
                item['time'] = 'None'

            # Genre cinématographique
            try:
                item['genre'] = list_films.css('div.meta-body-item.meta-body-info span::text')[1].get()
            except:
                 item['genre'] = 'None'

            # Score du film
            try:
                item['score'] = list_films.css('span.stareval-note::text')[0].get()
            except:
                item['score'] = 'None'

            # Description du film
            try:
                item['desc'] = list_films.css('div.content-txt ::text')[0].get()
            except:
                item['desc'] = 'None'

            # Date de sortie
            try:
                item['release'] = list_films.css('span.date::text')[0].get()
            except:
                item['release'] = 'None'


            yield item

# %% [markdown]
# ## 4.7 Ajoutez l'ensemble de votre code au fichier `allocine.py` se trouvant dans le dossier `spider`, exécutant la commande suivante afin d'obtenir le fichier `allocine.csv` contenant les données collectées.

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl allocine -o allocine.csv
# Out:
# 2023-12-13 10:32:12 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: WebCrawler)
# 2023-12-13 10:32:12 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22621-SP0
# 2023-12-13 10:32:12 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-13 10:32:12 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-12-13 10:32:12 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-12-13 10:32:12 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-12-13 10:32:12 [scrapy.extensions.telnet] INFO: Telnet Password: d48253cbfc11c44a
# 2023-12-13 10:32:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-13 10:32:12 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-12-13 10:32:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-13 10:32:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-13 10:32:12 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-13 10:32:12 [scrapy.core.engine] INFO: Spider opened
# 2023-12-13 10:32:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-13 10:32:12 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-12-13 10:32:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/robots.txt> (referer: None)
# 2023-12-13 10:32:13 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET http://www.allocine.fr/film/meilleurs/> from <GET https://www.allocine.fr/film/meilleurs>
# 2023-12-13 10:32:13 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.allocine.fr/film/meilleurs/> from <GET http://www.allocine.fr/film/meilleurs/>
# 2023-12-13 10:32:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/> (referer: None)
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
#
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': 'Romance',
#  'image': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2023-12-13 10:32:13 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-13 10:32:13 [scrapy.extensions.feedexport] INFO: Stored csv feed (10 items) in: allocine.csv
# 2023-12-13 10:32:13 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 918,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 4,
#  'downloader/response_bytes': 61358,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/301': 2,
#  'elapsed_time_seconds': 0.576267,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 13, 9, 32, 13, 544394, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 467340,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 10,
#  'log_count/DEBUG': 17,
#  'log_count/INFO': 11,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2023, 12, 13, 9, 32, 12, 968127, tzinfo=datetime.timezone.utc)}
# 2023-12-13 10:32:13 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## 4.7 Importez la bibliothèque Pandas puis visualisez votre collecte de données

# %% [markdown]
# # Partie 2 - Cotations boursières du CAC40 - [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
#
#
# <img src='data:image/png;base64,...'>
#
#
#
# L'objectif de cet exercice sera de collecter les données en temps réelle des actions du CAC40.
# Les données que nous collecterons serons :
#
# - le nom de l'indice boursier
# - le cours de l'action
# - la variation de l'action
# - la valeur la plus haute de la séance
# - la valeur la plus basse
# - la valeur d'ouverture
# - la date et l'heure de la collecte
#
#
# ## Lancez le projet scrapy
#
# Créez le projet scrapy nomé `boursorama` en utilisant le lien suivant `https://www.boursorama.com/bourse/actions/palmares/france/page-1`.
#
# Pour rappel la commande scrapy pour génére un nouveau spider est la suivante :
#
# `scrapy genspider nom_du_projet adresse_url`

# %%
# !cd WebCrawler && scrapy genspider boursorama https://www.boursorama.com/bourse/actions/palmares/france/page-1
# Out:
# Created spider 'boursorama' using template 'basic' in module:
#   WebCrawler.spiders.boursorama

# %% [markdown]
# ## Modifiez le fichier items.py en ajoutant les champs à collecter
#
# Ajoutez une class `ReviewsBoursoramaItem(scrapy.Item)` puis les champs avec la nomenclature `name = scrapy.Field()`

# %% [markdown]
# ## Lancez le shell scrapy

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC'`
#
# `fetch(url)`

# %% [markdown]
# ## Compléter le code suivant puis ajoutez-le au fichier `boursorama.py`.

# %%
import scrapy
from scrapy import Request
import time
from WebCrawler.items import ReviewsBoursorama
from datetime import datetime


class BoursoramaSpider(scrapy.Spider):
    name = 'boursorama'
    allowed_domains = ['finance.yahoo.com']
    start_urls = [f'https://www.boursorama.com/bourse/actions/palmares/france/page-{n}' for n in range(1,10)]
    database = DataBase('database')

    try:
        self.database.create_table('boursorama',
                                    indice = db.String,
                                    cours = db.String,
                                    var  = db.String,
                                    high  = db.String,
                                    low  = db.String,
                                    open_  = db.String,
                                    time  = db.String
                                    )
    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_boursorama)

    def parse_boursorama(self, response):
        liste_indices = response.css('tr.c-table__row')[3:]

        for indices in liste_indices:
            item = ReviewsBoursorama()

            #indice boursier
            try:
                item['indice'] = indices.css('a.c-link::text').get()
            except:
                item['indice'] = 'None'

            #indice cours de l'action
            try:
                item['cours'] = indices.css('span.c-instrument--last::text').get()
            except:
                item['cours'] = 'None'

            #Variation de l'action
            try:
                item['var'] =  indices.css('span.c-instrument--instant-variation::text').get()
            except:
                item['var'] = 'None'

            #Valeur la plus haute
            try:
                item['high'] =  indices.css('span.c-instrument--high::text').get()
            except:
                item['high'] = 'None'

            #Valeur la plus basse
            try:
                item['low'] = indices.css('span.c-instrument--low::text').get()
            except:
                item['low'] = 'None'

            #Valeur d'ouverture
            try:
                item['open_'] = indices.css('span.c-instrument--open::text').get()
            except:
                item['open_'] = 'None'

            #Date de la collecte
            try:
                item['time'] = datetime.today()
            except:
                item['time'] = 'None'
            self.database.add_row('boursorama', item)
            yield item

# %% [markdown]
# ## Executez la commande suivante afin de collecter vos données

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl boursorama -o boursorama.csv
# Out:
# Table : 'boursorama' are created succesfully
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# 2023-12-13 14:04:47 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: WebCrawler)
# 2023-12-13 14:04:47 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22621-SP0
# 2023-12-13 14:04:47 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-13 14:04:47 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-12-13 14:04:47 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-12-13 14:04:47 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-12-13 14:04:47 [scrapy.extensions.telnet] INFO: Telnet Password: b03501dac7ab091c
# 2023-12-13 14:04:48 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-13 14:04:48 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-12-13 14:04:48 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-13 14:04:48 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-13 14:04:48 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-13 14:04:48 [scrapy.core.engine] INFO: Spider opened
# 2023-12-13 14:04:48 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-13 14:04:48 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-13 14:04:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boursorama.com/robots.txt> (referer: None)
# 2023-12-13 14:04:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boursorama.com/bourse/actions/palmares/france/page-1> (referer: None)
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '2.374 ',
#  'high': '2.440 ',
#  'indice': 'SOLUTIONS 30',
#  'low': '2.312 ',
#  'open_': '2.314 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 88871),
#  'var': '+4.58%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '95.140 ',
#  'high': '96.620 ',
#  'indice': 'ARKEMA',
#  'low': '92.540 ',
#  'open_': '93.380 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 95886),
#  'var': '+4.18%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '112.000 ',
#  'high': '112.400 ',
#  'indice': 'SES IMAGOTAG',
#  'low': '109.200 ',
#  'open_': '109.200 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 100417),
#  'var': '+2.75%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '8.170 ',
#  'high': '8.270 ',
#  'indice': 'VOLTALIA',
#  'low': '7.750 ',
#  'open_': '7.890 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 104419),
#  'var': '+2.00%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '14.540 ',
#  'high': '14.560 ',
#  'indice': 'CARMILA',
#  'low': '14.280 ',
#  'open_': '14.320 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 108921),
#  'var': '+1.68%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '192.900 ',
#  'high': '193.400 ',
#  'indice': 'SOPRA STERIA',
#  'low': '190.100 ',
#  'open_': '190.100 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 112928),
#  'var': '+1.63%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '27.140 ',
#  'high': '27.240 ',
#  'indice': 'NEOEN',
#  'low': '26.460 ',
#  'open_': '26.560 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 117926),
#  'var': '+1.57%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '0.559 ',
#  'high': '0.569 ',
#  'indice': 'CGG',
#  'low': '0.555 ',
#  'open_': '0.567 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 122457),
#  'var': '+1.53%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '28.100 ',
#  'high': '28.240 ',
#  'indice': 'SCOR',
#  'low': '27.650 ',
#  'open_': '27.720 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 126460),
#  'var': '+1.48%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '19.240 ',
#  'high': '19.435 ',
#  'indice': 'FORVIA',
#  'low': '18.875 ',
#  'open_': '18.900 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 130024),
#  'var': '+1.48%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '81.750 ',
#  'high': '82.300 ',
#  'indice': 'WENDEL',
#  'low': '80.750 ',
#  'open_': '80.750 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 134980),
#  'var': '+1.43%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '2 034.500 ',
#  'high': '2 043.500 ',
#  'indice': 'HERMES INTL',
#  'low': '2 006.500 ',
#  'open_': '2 009.000 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 138979),
#  'var': '+1.24%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '9.004 ',
#  'high': '9.080 ',
#  'indice': 'VIVENDI',
#  'low': '8.928 ',
#  'open_': '8.928 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 142491),
#  'var': '+1.17%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '185.680 ',
#  'high': '187.200 ',
#  'indice': 'ESSILORLUXOTTICA',
#  'low': '183.100 ',
#  'open_': '183.100 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 147496),
#  'var': '+1.15%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '21.210 ',
#  'high': '21.215 ',
#  'indice': 'STELLANTIS',
#  'low': '20.930 ',
#  'open_': '20.945 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 152025),
#  'var': '+1.12%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '102.500 ',
#  'high': '102.900 ',
#  'indice': 'IPSEN',
#  'low': '101.700 ',
#  'open_': '101.700 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 156020),
#  'var': '+0.99%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '298.000 ',
#  'high': '300.000 ',
#  'indice': 'VIRBAC',
#  'low': '291.500 ',
#  'open_': '292.000 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 160022),
#  'var': '+0.85%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '138.600 ',
#  'high': '139.100 ',
#  'indice': 'THALES',
#  'low': '138.050 ',
#  'open_': '138.350 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 164545),
#  'var': '+0.84%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '22.200 ',
#  'high': '22.220 ',
#  'indice': 'RUBIS',
#  'low': '21.940 ',
#  'open_': '22.000 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 169549),
#  'var': '+0.82%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '16.114 ',
#  'high': '16.162 ',
#  'indice': 'ENGIE',
#  'low': '16.024 ',
#  'open_': '16.062 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 173073),
#  'var': '+0.78%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '33.150 ',
#  'high': '33.600 ',
#  'indice': 'MERSEN',
#  'low': '33.000 ',
#  'open_': '33.000 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 177074),
#  'var': '+0.76%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '24.810 ',
#  'high': '25.090 ',
#  'indice': 'REXEL',
#  'low': '24.660 ',
#  'open_': '24.660 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 181072),
#  'var': '+0.73%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '63.470 ',
#  'high': '63.780 ',
#  'indice': 'SAINT-GOBAIN',
#  'low': '63.280 ',
#  'open_': '63.390 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 185586),
#  'var': '+0.73%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '11.280 ',
#  'high': '11.340 ',
#  'indice': 'COFACE',
#  'low': '11.170 ',
#  'open_': '11.170 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 190588),
#  'var': '+0.71%'}
# 2023-12-13 14:04:49 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1>
#
# {'cours': '25.980 ',
#  'high': '26.240 ',
#  'indice': 'IMERYS',
#  'low': '25.840 ',
#  'open_': '25.840 ',
#  'time': datetime.datetime(2023, 12, 13, 14, 4, 49, 195101),
#  'var': '+0.70%'}
# 2023-12-13 14:04:49 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-13 14:04:49 [scrapy.extensions.feedexport] INFO: Stored csv feed (25 items) in: boursorama.csv
# 2023-12-13 14:04:49 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 485,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 89543,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.781154,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 13, 13, 4, 49, 200107, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 573400,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 25,
#  'log_count/DEBUG': 30,
#  'log_count/INFO': 11,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 13, 13, 4, 48, 418953, tzinfo=datetime.timezone.utc)}
# 2023-12-13 14:04:49 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Bonus - [MyAnimeListe](https://myanimelist.net/manga.php?letter=A)
#
# <img src='https://image.myanimelist.net/ui/OK6W_koKDTOqqqLDbIoPArR89MP-ulHxaLCJ2P-BfXg'>
#
# Reproduisez l'ensemble de la procédure en collectant les données du site [MyAnimeListe](https://myanimelist.net/manga.php?letter=A).
#
# Les données à collecter :
# - le nom des animés
# - l'image des animés
# - la description des animés.
#
# Utilisez la class `DataBase` pour stoquer vos donneés dans une base de données.

# %%
#fais dans un fichier a part dans le spider

# %%
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='database'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')


    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table)

        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
#Générer un projet scrapy
# !cd WebCrawler && scrapy genspider manga
# Out:
# Table : 'boursorama' are created succesfully
# Table : 'anime' are created succesfully
# Usage
# =====
#   scrapy genspider [options] <name> <domain>
#
# Generate new spider using pre-defined templates
#
# Options
# =======
#   -h, --help            show this help message and exit
#   -l, --list            List available templates
#   -e, --edit            Edit spider after creating it
#   -d TEMPLATE, --dump TEMPLATE
#                         Dump template to standard output
#   -t TEMPLATE, --template TEMPLATE
#                         Uses a custom template.
#   --force               If the spider already exists, overwrite it with the
#                         template
#
# Global Options
# --------------
#   --logfile FILE        log file. if omitted stderr will be used
#   -L LEVEL, --loglevel LEVEL
#                         log level (default: DEBUG)
#   --nolog               disable logging completely
#   --profile FILE        write python cProfile stats to FILE
#   --pidfile FILE        write process ID to FILE
#   -s NAME=VALUE, --set NAME=VALUE
#                         set/override setting (may be repeated)
#   --pdb                 enable pdb on failure

# %%
lettres_alphabet = [chr(i) for i in range(ord('A'), ord('Z') + 1)]
URLSCRAP = "https://myanimelist.net/manga.php?letter="

# %%
# Collecter les données
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl manga -o manga.csv
# Out:
# Table : 'boursorama' are created succesfully
# 2023-12-13 15:47:07 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: WebCrawler)
# 2023-12-13 15:47:07 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22621-SP0
# 2023-12-13 15:47:07 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-12-13 15:47:07 [asyncio] DEBUG: Using selector: SelectSelector
# 2023-12-13 15:47:07 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2023-12-13 15:47:07 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2023-12-13 15:47:07 [scrapy.extensions.telnet] INFO: Telnet Password: 7caf312e4c4dcceb
# 2023-12-13 15:47:07 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-12-13 15:47:07 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2023-12-13 15:47:07 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-12-13 15:47:07 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-12-13 15:47:07 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-12-13 15:47:07 [scrapy.core.engine] INFO: Spider opened
# 2023-12-13 15:47:07 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-12-13 15:47:07 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-12-13 15:47:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/robots.txt> (referer: None)
# 2023-12-13 15:47:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://myanimelist.net/manga.php?letter=A> (referer: None)
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'The representative of "purity," and the nation\'s most '
#                 'popular actress, Yeo Goeun, and the twisted scandal maker, '
#                 'Seo Beomi. In truth, the two of them share a secret. They are '
#                 '"acting as best friends"...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/290474.jpg?s=17c107c1dcc622bb1a44b7fd49a0340d',
#  'nom': 'A Beastly Scandal'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Kyouko, a university student, is in love with her best friend '
#                 "Masumi, and is getting to the point where she can't stand it "
#                 'any more. Cue alcohol.',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/29040.jpg?s=da0684ee69a01025d5d9e9d9f5738405',
#  'nom': 'A Bewildering Flower'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'The antics of two high school girls: Kim Peongyon and Choi '
#                 'Boa. Kim, aka "Bias Girl," is a foul mouthed, overactive girl '
#                 'and idiot who has weird and strange biased ideas about people '
#                 'and things, and B...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/150659.jpg?s=0b3cf5cc073d3e95c65a6e19294de245',
#  'nom': 'A Bias Girl'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Middle school, year 2, summer. The me who was unable to say '
#                 '"don\'t go" or that "I liked you" to her in the past appeared '
#                 'before me 3 years later. The story of a boy and a girl '
#                 'confronting the time spe...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/264058.jpg?s=97ba0fa8bc2f663d22337f36cf12f4b3',
#  'nom': 'A Bitch and a Punk'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'A collection of sweet stories about couples and singles, '
#                 "office workers and unemployed people. But be warned: there's "
#                 'more than a touch of bitterness here. (Source: Naver)',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/148197.jpg?s=185cdf72e9975a63bb2974dd5cee2490',
#  'nom': 'A Bittersweet Life'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'When she interviewed for a job at an antique bookstore, Bora '
#                 "Kang definitely wasn't expecting to witness the magical "
#                 'events she did. Having found out these long-kept secrets of '
#                 'the bookstore, she is f...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/267631.jpg?s=2d92675323406a2dc101ab0d9c4fe6a8',
#  'nom': 'A Bookstore Romance'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'This one shot has won 3rd spot of Daewon manwha contest, and '
#                 'thus the author has a high(er) chance of being employed by '
#                 "Issue magazine. (Source: Sura's Place)",
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/5/111613.jpg?s=2cd899e100bd6863eb8b02720e3038f0',
#  'nom': 'A Boy Who Fishes Dreams'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': '1. A Boy. A Girl. 2. Ariya Nashiya 3. Kinmokusei 4. Baby '
#                 'Berry Kiss 5. Kono Koi to...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/248756.jpg?s=5184e7d8dc5f912e04895426130f5869',
#  'nom': 'A Boy. A Girl.'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "In an attempt to ward off yet another one of Jin Yeong-seo's "
#                 "suitors, Shin Ha-ri goes on a blind date in her best friend's "
#                 'place with the goal of ruining the meeting. Arriving in a '
#                 'thick layer of make...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/242318.jpg?s=b01d875ae77d71fa10ac1e4cb74b2363',
#  'nom': 'A Business Proposal'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Jin Young is a good student with good grades, but she has a '
#                 'little bit of an unstable mind. Hye Jung is a cheerful girl '
#                 'who helps out at her mom\'s "snack shop", a sort of small '
#                 'restaurant that offers...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/264105.jpg?s=5ec2ea668937abd8da126feb2e434c61',
#  'nom': 'A Cat and a Bird'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'The heartwarming story of two young people who love each '
#                 'other but can not be together. ',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/22621.jpg?s=14e48bb6cd7f4b3d87a5cf74e0485dad',
#  'nom': 'A Cat That Loved a Fish'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Sisters Ju-eun and Hyejin grew up in absolute poverty. After '
#                 "their mother's death, Hyejin accepts the offer to join their "
#                 "estranged father's wealthy family. But when Hyejin turns out "
#                 'dead just three y...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/264426.jpg?s=49af25d4d2147b162d0cc1996a5956f7',
#  'nom': 'A Chance at Last'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'A novel based off of the eroge Tokeijikake no Ley-Line.',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/4/90615.jpg?s=ba4012660ed0fdc354586b8b0f1e5270',
#  'nom': 'A Clockwork Ley-Line: Unmei no Mawaru Mori'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Sang, once the little boy too afraid to jump into the lake '
#                 'with the older children, comes back home a brave new man—a '
#                 "huntsman, to be exact. It's only after reuniting with his "
#                 'friend Sejin, the shaman...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/265404.jpg?s=cdf32a9de4c7fd789cd5dd526b720997',
#  'nom': 'A Compendium of Ghosts'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': '"If you sign this paper, then Milady will become the Duchess '
#                 'of Leviaus for the next year. In exchange, you will receive a '
#                 'deposit of 100,000 rubles and if you fulfil the terms of the '
#                 'contract success...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/276848.jpg?s=b08dd4e8a2db3e15974e9ad70dfee292',
#  'nom': "A Con Artist, but That's Okay"}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'When his musician sister suddenly goes missing, wood sculptor '
#                 'Baek Beom is thrown into the world of Artificers, immortal '
#                 'beings that obtain magical abilities through mastery of their '
#                 'craft. Determined...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/290147.jpg?s=50f05b525d54476ad6c1121f21f8cf58',
#  'nom': 'A Country of Maestri'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': None,
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/171742.jpg?s=22d1ab40484961b1b049c6d59eb6339c',
#  'nom': 'A Course'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': '1. A Cup of... 2. Shunshoku no Shouzou 3. *Blossom Season* 4. '
#                 'Aka Ito Reel 5. Poco a Poco',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/100619.jpg?s=c69a96427537e7132031acdf5e460b2e',
#  'nom': 'A Cup of...'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Kidnapped as a child to be trained in the art of poison, '
#                 'Sohan Jin returns to his hometown in search of the group of '
#                 'New Moon Sword Dancers who raised him. However, upon his '
#                 'return, Sohan discovers th...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/265031.jpg?s=9b2f0316347abca53ae987692d3821e4',
#  'nom': 'A Dance of Swords in the Night'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Included one-shot: Still Blue',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/13274.jpg?s=8068e6de5fbe450a5d5e62b1ae077edb',
#  'nom': 'A Day In The Life'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': None,
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/68759.jpg?s=c9589223078fada8f21bc5e24816a67b',
#  'nom': 'A Day in the Typhoon'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'A secret love story the world can never know, filled with '
#                 'long lost treasures, a runaway prince and a part time '
#                 'delivery girl. Can two strangers find true love in a single '
#                 'day? To raise money for her...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/266714.jpg?s=2f54fdb979fe23bb8d0c1d4dce72254d',
#  'nom': 'A Day of the Prince'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "What's better than a good meal? My name's Jaeho and I love "
#                 "food. While some may call me a deadbEAT because I don't have "
#                 "a job at the moment, I'm just your normal happy guy who loves "
#                 'eating and my girl...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/261951.jpg?s=da802461a1618b96aca40ae02bf83fb6',
#  'nom': "A DeadbEAT's Meal"}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'A man named Lee Jung-yool appears out of nowhere in Han '
#                 "Gitae's detective agency, and Gitae suddenly finds himself "
#                 'under threats to cooperate with his plans...! What exactly is '
#                 'the massive conspiracy...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/263890.jpg?s=85f8f6ab40b9cec435cecb5fde5eb2d9',
#  'nom': 'A Declaration of Revenge'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "Sonidor is a dream artisan who enters into other people's "
#                 'dreams through physical contact and grants wishes that cannot '
#                 'be fulfilled in reality. One day, the emperor suddenly '
#                 'arrives at her house and...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/273407.jpg?s=666a1476cdb6c9d1b0f226f486ed0600',
#  'nom': 'A Dream Escape'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'There once was a princess who fell for a curse. Countless '
#                 'times have a knight come in vain attempts to save the poor '
#                 'princess. They all failed, killed by a demon. When a knight '
#                 'finally comes to defeat...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/126409.jpg?s=e95dda2db6666ebc8e162cea73dd6701',
#  'nom': 'A Fairytale for the Demon Lord'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Guys like Woojin have it all: the looks, personality, and '
#                 "background to be popular. There's no way Woojin would take "
#                 'interest in a nobody like Yunwoo, but Yunwoo ends up falling '
#                 'for Woojin and telling...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/272467.jpg?s=b654dd88e236f84359e90ea088dfe69a',
#  'nom': 'A Fine Line'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Top actress Lee Sia has the ability to see ghosts. After an '
#                 'accident, she wakes up in the body of "Camilla Sorfel." The '
#                 'problem is that—"Oh, father! Help me!"—she is fated to die no '
#                 'matter what! Prolo...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/289460.jpg?s=77878cd216fa1fd2651431f67b7e6955',
#  'nom': 'A Fortune-Telling Princess'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Kazao is happy with his life on Mirai ("Future") Island. '
#                 'Sure, his parents abandoned him after he was born, leaving '
#                 'him to be raised at the orphanage-like facility, but his life '
#                 'is comfortable and has...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/34978.jpg?s=d119c56eca505ecc5c5c580d3aa05b5a',
#  'nom': 'A Girls'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Schoolteacher Han Hana is afflicted with a certain family '
#                 'curse that has ruined every single one of her past '
#                 'relationships. The curse in question: whenever she kisses '
#                 'someone, she will turn into a dog...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/225965.jpg?s=9ea3546c024adc35ef31a42b0c3996d6',
#  'nom': 'A Good Day to Be a Dog'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "Hosoo's uneventful days are spent caring for his sick younger "
#                 'sister, when TV star and singer Esau enters his life. The '
#                 'dazzling celeb had been laying low because a woman claiming '
#                 'to be his birth moth...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/235912.jpg?s=663a37171016ce71acea9d1747562a98',
#  'nom': 'A Good Day to Go Crazy'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Kang Jinha is at the top of his class, handsome, and '
#                 'exceptionally talented—unlike Go Siwon, who is average at '
#                 'best and easily blends into the crowd. Given their '
#                 'differences, Siwon keeps a safe distan...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/259559.jpg?s=3159e5198eda15dcda4f01e3c69e99c8',
#  'nom': 'A Guy Like You'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Moosung is an inn server with a huge crush on Soyeon, a '
#                 'beautiful woman from an influential family. Unfortunately, '
#                 "she's only willing to marry... a very handsome swordsman. Now "
#                 "Moosung's life mission...",
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/279439.jpg?s=c8a99579eaba01d93f0e73a51d7c85c1',
#  'nom': 'A Handsome Swordsman'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Our protagonist ends her day as usual, rereading her favorite '
#                 'novel before sleep. But, after awakening in the body of '
#                 'Princess Charlioni of the Kingdom of Linoa, the protagonist '
#                 'of that very novel, sh...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/261656.jpg?s=4c519ff08ba861ce6f69338680e90730',
#  'nom': 'A Heart for the Emperor'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "One man's death led to another man's salvation. After years "
#                 'of suffering from heart disease, Da-ul receives a heart '
#                 'transplant from young and renowned pianist Yuwon, who has '
#                 'died an unfortunate death...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/275140.jpg?s=ff6e134c7a55eb94319c9cc2ddb46ab9',
#  'nom': 'A Heartfelt Andante'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': None,
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/288266.jpg?s=a43f7ac6b9ea339f394b76eb3e949132',
#  'nom': 'A House for Samsami'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Young actress Joo Arin is set to make her big-screen debut, '
#                 'but while preparing for the role, she comes across a bit of a '
#                 'problem... She has to film a kiss scene even though she '
#                 "hasn't even had her fi...",
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/284208.jpg?s=94e14a432d57e6310d5eb73c23a3f0e3',
#  'nom': 'A Kiss Is Not Enough'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Everyone always says to set high goals for oneself. Sei-Ann, '
#                 'an orphaned young lady who was raised in the care of a '
#                 "noblewoman, does just that when she decides she'll become the "
#                 "prince's bride. With a...",
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/261174.jpg?s=a779c8a0f41f25085b4f8578915d5011',
#  'nom': 'A Kiss to the Prince'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': '1. Kohrogi 2. NOIZ 3. dZi:s 4. X-connection2001',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/30011.jpg?s=19bb2bceab5f2bdfb3bf232e81d0a6ec',
#  'nom': 'A la Carte'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "It's about four people. A young police man who joined the "
#                 'force so he could beat people up legally. While he was on the '
#                 'join he messed up and was almost fired but instead was given '
#                 'the job of body gua...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/25274.jpg?s=1a3482f99254480b69f71cbfd07b143a',
#  'nom': 'A Love Guard'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'After an accident die, Ria become angels bring number 5623. '
#                 'She still can not forget things when alive day and night to '
#                 'remember Ban Ji Hwan, the earthly boyfriend. A year passed, '
#                 'that called Ria acci...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/18737.jpg?s=720eda5f74c810365dc40b0a59fce4e2',
#  'nom': 'A Love in 100 Days'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "What's it like spending your whole life coming in second "
#                 "place? Ask Nam Jinwoo: he's been living in the shadow of his "
#                 'rival, Ma Sangtae, his whole life. Now the two are even '
#                 'working in the same office...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/259890.jpg?s=1a39d58594e3ddabf180d84760c6f897',
#  'nom': 'A Man of Virtue'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Yuhyeon becomes the youngest CEO of Hansung, a successful '
#                 'electronics company built on toxic work culture, but nobody '
#                 'he cares about is there to celebrate with him. After a night '
#                 'of drinking and wonde...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/263998.jpg?s=2cf0ef0d5573874b530f7571ed304a4f',
#  'nom': "A Man's Man"}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Innocent man framed for murder and sentenced to death. '
#                 'Released 17 years later after his name was cleared. The times '
#                 'have changed. Yeop has changed. His friends and family have '
#                 'changed. Nothing is the...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/263290.jpg?s=c08599405a97729ff96d94381acfd4b4',
#  'nom': 'A Mark Against Thee'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Empress Olivia knows happiness is the last thing she '
#                 'deserves, but when she finally becomes pregnant with the '
#                 "emperor's child, she thinks things might finally be taking a "
#                 'turn for the better. Alas, Ol...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/266557.jpg?s=159569972d62c7f54eeec7e8f3b9b681',
#  'nom': 'A Marriage Alliance for Revenge'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'The strongest in murim, Cheon Nyeon-bi. She was betrayed by '
#                 'her lover and met a tragic death, but soon after, she woke up '
#                 "in a concubine's body. She was only confused for a moment. "
#                 'Cheon Nyeon-bi, who...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/285096.jpg?s=3de55999e427fd87437b8767fd5cfdb9',
#  'nom': 'A Martial Master Wakes Up as a Concubine'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'Lilienne Islar died an abusive mother, a neglected wife, and '
#                 'a cast-off stepsister. So when she suddenly opens her eyes '
#                 'again as her younger self, she decides to set things right '
#                 'with the people in he...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/3/264876.jpg?s=b608419f3ea1dec5357825b2aeda6035',
#  'nom': 'A Match Made in Mana'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': "Rent-free living? What's the catch? When her mom gets a new "
#                 'boyfriend, 19-year-old Soohyun decides to move out. In a '
#                 'stroke of luck, her college classmate Yujin offers for her to '
#                 'move in for free, no...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/271825.jpg?s=77df33ae23887fe8d22105349633bce8',
#  'nom': 'A Matter of Time'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'I was a public official who worked part-time to survive. I '
#                 'was knocked out by a speeding car while making deliveries in '
#                 'the middle of the night. I have a strong memory of dying '
#                 'prematurely in a hit-an...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/1/281309.jpg?s=faacdad352fab31375e7cfbd6cc02b8a',
#  'nom': 'A Modern Man Who Got Transmigrated Into the Murim World'}
# 2023-12-13 15:47:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://myanimelist.net/manga.php?letter=A>
#
# {'description': 'I, a great monster killer, was about to plunge my knife into '
#                 "a vampire's heart to avenge my parents' death... when I woke "
#                 "up in a princess's body instead! All I want is to return to "
#                 'my world so I can...',
#  'image': 'https://cdn.myanimelist.net/r/50x70/images/manga/2/264993.jpg?s=c467f86c475c29e8af80d09534ad6dfc',
#  'nom': 'A Monster Hunter Becomes a Princess'}
# 2023-12-13 15:47:09 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-12-13 15:47:09 [scrapy.extensions.feedexport] INFO: Stored csv feed (50 items) in: manga.csv
# 2023-12-13 15:47:09 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 460,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 229771,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 1.875523,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 12, 13, 14, 47, 9, 701106, tzinfo=datetime.timezone.utc),
#  'item_scraped_count': 50,
#  'log_count/DEBUG': 55,
#  'log_count/INFO': 11,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 12, 13, 14, 47, 7, 825583, tzinfo=datetime.timezone.utc)}
# 2023-12-13 15:47:09 [scrapy.core.engine] INFO: Spider closed (finished)
# Table : 'anime' are created succesfully
# oui
# 50
